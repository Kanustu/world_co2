# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from first_glance import report
from co2_module import functions
from co2_module.functions import country_demo

# %%
# Initial look using first_glance stats_report
report.stats_report('global_co2.csv')
# Out:
#                   entry_count data_type  null_count          mean  \
# country                 48058    object           0           NaN
# year                    48058     int64           0  1.926843e+03
# population              48058   float64        8563  6.083223e+07
# gdp                     48058   float64       33494  2.677586e+11
# cement_co2              48058   float64       24294  9.109400e+00
# co2                     48058   float64       17750  3.912722e+02
# coal_co2                48058   float64       22983  1.569639e+02
# gas_co2                 48058   float64       22975  5.127810e+01
# oil_co2                 48058   float64       22947  1.129207e+02
# share_global_co2        48058   float64       19563  5.163432e+00
#
#                            std         min           25%           50%  \
# country                    NaN         NaN           NaN           NaN
# year              5.941485e+01      1750.0  1.883000e+03  1.930000e+03
# population        3.285867e+08       222.0  3.464375e+05  2.456362e+06
# gdp               2.103151e+12  49980000.0  7.516679e+09  2.597999e+10
# cement_co2        6.646355e+01         0.0  0.000000e+00  2.900000e-02
# co2               1.855825e+03         0.0  1.830000e-01  3.856000e+00
# coal_co2          7.657201e+02         0.0  0.000000e+00  7.030000e-01
# gas_co2           3.160338e+02         0.0  0.000000e+00  0.000000e+00
# oil_co2           6.294511e+02         0.0  8.400000e-02  1.323000e+00
# share_global_co2  1.834465e+01         0.0  2.000000e-03  3.700000e-02
#
#                            75%           max
# country                    NaN           NaN
# year              1.976000e+03  2.022000e+03
# population        1.008038e+07  7.975105e+09
# gdp               1.132942e+11  1.136302e+14
# cement_co2        8.340000e-01  1.692404e+03
# co2               4.727725e+01  3.714979e+04
# coal_co2          1.698800e+01  1.521930e+04
# gas_co2           1.344500e+00  7.922112e+03
# oil_co2           1.391600e+01  1.237795e+04
# share_global_co2  5.180000e-01  1.000000e+02

# %%
df = pd.read_csv('global_co2.csv')

# %%
# Creating a regex pattern to filter out specific entries from the DataFrame
exclude_list = ['World', 'Europe', 'countries', 'GCP', 'Asia', 'Africa', 'America', 'International']

# Join the list into a single regex pattern
pattern = '|'.join(exclude_list)

# Create a copy of the original DataFrame to work on
co2_df = df.copy()
#co2_df['year'] = pd.to_datetime(co2_df['year'], format='%Y')
# Filter the DataFrame to exclude rows where the 'country' column contains any of the patterns in exclude_list
co2_countries = co2_df[~co2_df['country'].str.contains(pattern, na=False, case=False, regex=True)]

# %%
#Cumulative Co2 emissions#
# Top 10 countries ordered by by cumulative co2 
functions.cumulative_co2(co2_countries, 'top', 10).style.highlight_max(color='lightblue')
# Out:
# <style type="text/css">
# #T_a3fc1_row0_col0, #T_a3fc1_row0_col1 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_a3fc1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3fc1_level0_col0" class="col_heading level0 col0" >country</th>
#       <th id="T_a3fc1_level0_col1" class="col_heading level0 col1" >co2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3fc1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a3fc1_row0_col0" class="data row0 col0" >United States</td>
#       <td id="T_a3fc1_row0_col1" class="data row0 col1" >426914.556000</td>
#     </tr>
#     <tr>
#       <th id="T_a3fc1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a3fc1_row1_col0" class="data row1 col0" >China</td>
#       <td id="T_a3fc1_row1_col1" class="data row1 col1" >260619.243000</td>
#     </tr>
#     <tr>
#       <th id="T_a3fc1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a3fc1_row2_col0" class="data row2 col0" >Russia</td>
#       <td id="T_a3fc1_row2_col1" class="data row2 col1" >119290.814000</td>
#     </tr>
#     <tr>
#       <th id="T_a3fc1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a3fc1_row3_col0" class="data row3 col0" >Germany</td>
#       <td id="T_a3fc1_row3_col1" class="data row3 col1" >93985.871000</td>
#     </tr>
#     <tr>
#       <th id="T_a3fc1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a3fc1_row4_col0" class="data row4 col0" >United Kingdom</td>
#       <td id="T_a3fc1_row4_col1" class="data row4 col1" >78834.706000</td>
#     </tr>
#     <tr>
#       <th id="T_a3fc1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a3fc1_row5_col0" class="data row5 col0" >Japan</td>
#       <td id="T_a3fc1_row5_col1" class="data row5 col1" >67734.911000</td>
#     </tr>
#     <tr>
#       <th id="T_a3fc1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a3fc1_row6_col0" class="data row6 col0" >India</td>
#       <td id="T_a3fc1_row6_col1" class="data row6 col1" >59740.694000</td>
#     </tr>
#     <tr>
#       <th id="T_a3fc1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a3fc1_row7_col0" class="data row7 col0" >France</td>
#       <td id="T_a3fc1_row7_col1" class="data row7 col1" >39397.693000</td>
#     </tr>
#     <tr>
#       <th id="T_a3fc1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a3fc1_row8_col0" class="data row8 col0" >Canada</td>
#       <td id="T_a3fc1_row8_col1" class="data row8 col1" >34613.228000</td>
#     </tr>
#     <tr>
#       <th id="T_a3fc1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a3fc1_row9_col0" class="data row9 col0" >Ukraine</td>
#       <td id="T_a3fc1_row9_col1" class="data row9 col1" >30961.508000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Top 10 years of cumulative co2 emissions
co2_df.groupby('year')[['co2', 'coal_co2', 'oil_co2', 'gas_co2', 'cement_co2']].sum().nlargest(10, 'co2').reset_index().style.highlight_max(color='lightblue')
# Out:
# <style type="text/css">
# #T_dcf52_row0_col0, #T_dcf52_row0_col1, #T_dcf52_row0_col2, #T_dcf52_row1_col3, #T_dcf52_row2_col4, #T_dcf52_row2_col5 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_dcf52">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dcf52_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_dcf52_level0_col1" class="col_heading level0 col1" >co2</th>
#       <th id="T_dcf52_level0_col2" class="col_heading level0 col2" >coal_co2</th>
#       <th id="T_dcf52_level0_col3" class="col_heading level0 col3" >oil_co2</th>
#       <th id="T_dcf52_level0_col4" class="col_heading level0 col4" >gas_co2</th>
#       <th id="T_dcf52_level0_col5" class="col_heading level0 col5" >cement_co2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dcf52_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dcf52_row0_col0" class="data row0 col0" >2022</td>
#       <td id="T_dcf52_row0_col1" class="data row0 col1" >237679.814000</td>
#       <td id="T_dcf52_row0_col2" class="data row0 col2" >65615.326000</td>
#       <td id="T_dcf52_row0_col3" class="data row0 col3" >52381.960000</td>
#       <td id="T_dcf52_row0_col4" class="data row0 col4" >37194.995000</td>
#       <td id="T_dcf52_row0_col5" class="data row0 col5" >7033.475000</td>
#     </tr>
#     <tr>
#       <th id="T_dcf52_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dcf52_row1_col0" class="data row1 col0" >2019</td>
#       <td id="T_dcf52_row1_col1" class="data row1 col1" >236804.780000</td>
#       <td id="T_dcf52_row1_col2" class="data row1 col2" >63757.935000</td>
#       <td id="T_dcf52_row1_col3" class="data row1 col3" >54128.837000</td>
#       <td id="T_dcf52_row1_col4" class="data row1 col4" >36884.891000</td>
#       <td id="T_dcf52_row1_col5" class="data row1 col5" >7054.495000</td>
#     </tr>
#     <tr>
#       <th id="T_dcf52_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dcf52_row2_col0" class="data row2 col0" >2021</td>
#       <td id="T_dcf52_row2_col1" class="data row2 col1" >236484.697000</td>
#       <td id="T_dcf52_row2_col2" class="data row2 col2" >64734.981000</td>
#       <td id="T_dcf52_row2_col3" class="data row2 col3" >50954.326000</td>
#       <td id="T_dcf52_row2_col4" class="data row2 col4" >38299.411000</td>
#       <td id="T_dcf52_row2_col5" class="data row2 col5" >7396.027000</td>
#     </tr>
#     <tr>
#       <th id="T_dcf52_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dcf52_row3_col0" class="data row3 col0" >2018</td>
#       <td id="T_dcf52_row3_col1" class="data row3 col1" >235455.960000</td>
#       <td id="T_dcf52_row3_col2" class="data row3 col2" >64199.107000</td>
#       <td id="T_dcf52_row3_col3" class="data row3 col3" >53688.346000</td>
#       <td id="T_dcf52_row3_col4" class="data row3 col4" >36409.482000</td>
#       <td id="T_dcf52_row3_col5" class="data row3 col5" >6852.412000</td>
#     </tr>
#     <tr>
#       <th id="T_dcf52_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dcf52_row4_col0" class="data row4 col0" >2017</td>
#       <td id="T_dcf52_row4_col1" class="data row4 col1" >231066.766000</td>
#       <td id="T_dcf52_row4_col2" class="data row4 col2" >63263.172000</td>
#       <td id="T_dcf52_row4_col3" class="data row4 col3" >53671.953000</td>
#       <td id="T_dcf52_row4_col4" class="data row4 col4" >34742.105000</td>
#       <td id="T_dcf52_row4_col5" class="data row4 col5" >6590.551000</td>
#     </tr>
#     <tr>
#       <th id="T_dcf52_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dcf52_row5_col0" class="data row5 col0" >2016</td>
#       <td id="T_dcf52_row5_col1" class="data row5 col1" >227618.087000</td>
#       <td id="T_dcf52_row5_col2" class="data row5 col2" >62590.770000</td>
#       <td id="T_dcf52_row5_col3" class="data row5 col3" >52852.505000</td>
#       <td id="T_dcf52_row5_col4" class="data row5 col4" >33991.622000</td>
#       <td id="T_dcf52_row5_col5" class="data row5 col5" >6489.787000</td>
#     </tr>
#     <tr>
#       <th id="T_dcf52_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dcf52_row6_col0" class="data row6 col0" >2015</td>
#       <td id="T_dcf52_row6_col1" class="data row6 col1" >227612.884000</td>
#       <td id="T_dcf52_row6_col2" class="data row6 col2" >64096.988000</td>
#       <td id="T_dcf52_row6_col3" class="data row6 col3" >52357.459000</td>
#       <td id="T_dcf52_row6_col4" class="data row6 col4" >33055.487000</td>
#       <td id="T_dcf52_row6_col5" class="data row6 col5" >6324.818000</td>
#     </tr>
#     <tr>
#       <th id="T_dcf52_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dcf52_row7_col0" class="data row7 col0" >2014</td>
#       <td id="T_dcf52_row7_col1" class="data row7 col1" >227582.200000</td>
#       <td id="T_dcf52_row7_col2" class="data row7 col2" >65481.224000</td>
#       <td id="T_dcf52_row7_col3" class="data row7 col3" >51206.221000</td>
#       <td id="T_dcf52_row7_col4" class="data row7 col4" >32448.060000</td>
#       <td id="T_dcf52_row7_col5" class="data row7 col5" >6552.658000</td>
#     </tr>
#     <tr>
#       <th id="T_dcf52_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dcf52_row8_col0" class="data row8 col0" >2013</td>
#       <td id="T_dcf52_row8_col1" class="data row8 col1" >226555.346000</td>
#       <td id="T_dcf52_row8_col2" class="data row8 col2" >65565.896000</td>
#       <td id="T_dcf52_row8_col3" class="data row8 col3" >51159.331000</td>
#       <td id="T_dcf52_row8_col4" class="data row8 col4" >32106.497000</td>
#       <td id="T_dcf52_row8_col5" class="data row8 col5" >6313.215000</td>
#     </tr>
#     <tr>
#       <th id="T_dcf52_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dcf52_row9_col0" class="data row9 col0" >2012</td>
#       <td id="T_dcf52_row9_col1" class="data row9 col1" >225160.414000</td>
#       <td id="T_dcf52_row9_col2" class="data row9 col2" >65333.733000</td>
#       <td id="T_dcf52_row9_col3" class="data row9 col3" >50952.808000</td>
#       <td id="T_dcf52_row9_col4" class="data row9 col4" >32064.065000</td>
#       <td id="T_dcf52_row9_col5" class="data row9 col5" >6068.376000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Yearly emissions percentages by industry
yearly_percent_industry = functions.percent_calc(co2_df.groupby('year').sum(), functions.calculations)
yearly_percent_industry = yearly_percent_industry.reset_index()[['year', 'coal_prct', 'oil_prct', 'gas_prct', 'cement_prct']]
yearly_percent_industry[yearly_percent_industry['year'].isin([1750, 2022])]
# Out:
#      year  coal_prct  oil_prct  gas_prct  cement_prct
# 0    1750     100.00      0.00      0.00         0.00
# 272  2022      27.61     22.04     15.65         2.96

# %%
df_melted = yearly_percent_industry.melt('year', var_name='Source', value_name='Emissions')

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_melted, x='year', y='Emissions', hue='Source')
plt.title('Total Emissions by Industry Over Time')
plt.savefig('industry_co2.png')
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ava/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniforge/base/envs/ava/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniforge/base/envs/ava/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/homebrew/Caskroom/miniforge/base/envs/ava/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/homebrew/Caskroom/miniforge/base/envs/ava/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/homebrew/Caskroom/miniforge/base/envs/ava/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
sns.lineplot(y=yearly_percent_industry['coal_prct'], x=yearly_percent_industry['year'])
plt.title('Total Percentage of CO2 From Coal')
plt.savefig('total_coal_co2.png')
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ava/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniforge/base/envs/ava/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
industry_prct_emiss = functions.percent_calc(co2_countries.copy(), functions.calculations)
industry_prct_emiss[industry_prct_emiss['country'].isin(['United States', 'China'])]
# Out:
#              country  year   population           gdp  cement_co2       co2  \
# 8950           China  1850  409821554.0  3.534960e+11         NaN       NaN
# 8951           China  1851  407570489.0           NaN         NaN       NaN
# 8952           China  1852  404611476.0           NaN         NaN       NaN
# 8953           China  1853  400951224.0           NaN         NaN       NaN
# 8954           China  1854  397324067.0           NaN         NaN       NaN
# ...              ...   ...          ...           ...         ...       ...
# 45774  United States  2018  332140032.0  1.814065e+13      38.971  5377.797
# 45775  United States  2019  334319680.0           NaN      40.896  5262.145
# 45776  United States  2020  335942016.0           NaN      40.688  4714.628
# 45777  United States  2021  336997632.0           NaN      41.312  5032.213
# 45778  United States  2022  338289856.0           NaN      41.418  5057.304
#
#        coal_co2   gas_co2   oil_co2  share_global_co2  coal_prct  oil_prct  \
# 8950        NaN       NaN       NaN               NaN        NaN       NaN
# 8951        NaN       NaN       NaN               NaN        NaN       NaN
# 8952        NaN       NaN       NaN               NaN        NaN       NaN
# 8953        NaN       NaN       NaN               NaN        NaN       NaN
# 8954        NaN       NaN       NaN               NaN        NaN       NaN
# ...         ...       ...       ...               ...        ...       ...
# 45774  1256.631  1619.275  2366.168            14.627      23.37     44.00
# 45775  1071.666  1675.471  2360.999            14.207      20.37     44.87
# 45776   877.920  1656.255  2047.544            13.467      18.62     43.43
# 45777  1004.531  1659.225  2239.014            13.668      19.96     44.49
# 45778   934.698  1743.539  2249.519            13.613      18.48     44.48
#
#        gas_prct  cement_prct
# 8950        NaN          NaN
# 8951        NaN          NaN
# 8952        NaN          NaN
# 8953        NaN          NaN
# 8954        NaN          NaN
# ...         ...          ...
# 45774     30.11         0.72
# 45775     31.84         0.78
# 45776     35.13         0.86
# 45777     32.97         0.82
# 45778     34.48         0.82
#
# [396 rows x 14 columns]

# %%
functions.industry_perct_emiss_country('United States', industry_prct_emiss)
# Out:
#              country  year       co2  coal_prct  oil_prct  gas_prct  \
# 45556  United States  1800     0.253     100.00      0.00      0.00
# 45557  United States  1801     0.267     100.00      0.00      0.00
# 45558  United States  1802     0.289     100.00      0.00      0.00
# 45559  United States  1803     0.297     100.00      0.00      0.00
# 45560  United States  1804     0.333     100.00      0.00      0.00
# ...              ...   ...       ...        ...       ...       ...
# 45774  United States  2018  5377.797      23.37     44.00     30.11
# 45775  United States  2019  5262.145      20.37     44.87     31.84
# 45776  United States  2020  4714.628      18.62     43.43     35.13
# 45777  United States  2021  5032.213      19.96     44.49     32.97
# 45778  United States  2022  5057.304      18.48     44.48     34.48
#
#        cement_prct
# 45556         0.00
# 45557         0.00
# 45558         0.00
# 45559         0.00
# 45560         0.00
# ...            ...
# 45774         0.72
# 45775         0.78
# 45776         0.86
# 45777         0.82
# 45778         0.82
#
# [223 rows x 7 columns]

# %%
sns.lineplot(x=functions.industry_perct_emiss_country('United States', industry_prct_emiss)['year'], y=functions.industry_perct_emiss_country('United States', industry_prct_emiss)['coal_prct'])
plt.title('United States Coal Percentage of Fossil Fuel Emissions')
plt.savefig('united_states_co2_emissions_plot.png')
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ava/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniforge/base/envs/ava/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
china = functions.industry_perct_emiss_country('China', industry_prct_emiss)
china
# Out:
#      country  year        co2  coal_prct  oil_prct  gas_prct  cement_prct
# 9007   China  1907     19.894     100.00      0.00      0.00          NaN
# 9008   China  1908     22.736     100.00      0.00      0.00          NaN
# 9009   China  1909     24.252     100.00      0.00      0.00          NaN
# 9010   China  1910     25.009     100.00      0.00      0.00          NaN
# 9011   China  1911     24.631     100.00      0.00      0.00          NaN
# ...      ...   ...        ...        ...       ...       ...          ...
# 9118   China  2018  10353.935      70.66     14.49      5.56         7.60
# 9119   China  2019  10721.042      70.17     14.55      5.88         7.71
# 9120   China  2020  10914.012      70.36     13.96      6.20         7.86
# 9121   China  2021  11336.233      70.39     13.80      6.74         7.52
# 9122   China  2022  11396.777      72.40     12.73      6.63         6.70
#
# [116 rows x 7 columns]

# %%
china[china['year'] >= 2018]
# Out:
#      country  year        co2  coal_prct  oil_prct  gas_prct  cement_prct
# 9118   China  2018  10353.935      70.66     14.49      5.56         7.60
# 9119   China  2019  10721.042      70.17     14.55      5.88         7.71
# 9120   China  2020  10914.012      70.36     13.96      6.20         7.86
# 9121   China  2021  11336.233      70.39     13.80      6.74         7.52
# 9122   China  2022  11396.777      72.40     12.73      6.63         6.70

# %%
sns.lineplot(x=functions.industry_perct_emiss_country('China', industry_prct_emiss)['year'], y=functions.industry_perct_emiss_country('China', industry_prct_emiss)['coal_prct'])
plt.title('China Coal Percentage of Fossil Fuel Emissions')
plt.savefig('china_co2_emissions_plot.png')
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ava/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniforge/base/envs/ava/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
per_cap_country = functions.per_capita_creation(co2_countries.copy())

# %%
per_cap_country[(per_cap_country['year'] == 2022) & (per_cap_country['country'].isin(['Qatar', 'United States', 'Canada', 'Australia', 'China']))].sort_values('co2_per_capita', ascending=False)
# Out:
#        year        country        co2  co2_per_capita
# 17501  2022          Qatar    101.340           37.60
# 1413   2022      Australia    392.279           14.99
# 23079  2022  United States   5057.304           14.95
# 4455   2022         Canada    547.944           14.25
# 4845   2022          China  11396.777            7.99

# %%
# Selecting highest 10 years of co2 per capita in Canada
per_cap_country[(per_cap_country['co2_per_capita'].notnull()) & (per_cap_country['country'] == 'China')].nlargest(10, 'co2_per_capita')\
[['country', 'year', 'co2_per_capita']]
# Out:
#      country  year  co2_per_capita
# 4845   China  2022            7.99
# 4844   China  2021            7.95
# 4843   China  2020            7.66
# 4842   China  2019            7.54
# 4841   China  2018            7.31
# 4836   China  2013            7.24
# 4837   China  2014            7.22
# 4835   China  2012            7.16
# 4840   China  2017            7.10
# 4838   China  2015            7.08

# %%
functions.per_cap_by_year(per_cap_country, 'top', 15, 2020)
# Out:
#     year                    country       co2  co2_per_capita
# 0   2020                      Qatar   102.501           37.13
# 1   2020                    Bahrain    37.396           25.31
# 2   2020                     Brunei    11.102           25.13
# 3   2020       United Arab Emirates   216.768           23.34
# 4   2020        Trinidad and Tobago    35.030           23.07
# 5   2020                     Kuwait    97.712           22.41
# 6   2020              New Caledonia     5.109           17.84
# 7   2020               Saudi Arabia   610.773           16.97
# 8   2020                  Australia   396.685           15.45
# 9   2020  Sint Maarten (Dutch part)     0.652           14.94
# 10  2020              Faroe Islands     0.758           14.45
# 11  2020                       Oman    65.429           14.40
# 12  2020              United States  4714.628           14.03
# 13  2020                     Canada   522.845           13.80
# 14  2020                 Kazakhstan   255.486           13.46

# %%
functions.per_cap_by_year(per_cap_country, 'bottom', 10, 2020)
# Out:
#    year                       country    co2  co2_per_capita
# 0  2020  Democratic Republic of Congo  3.710            0.04
# 1  2020                       Somalia  0.597            0.04
# 2  2020                       Burundi  0.736            0.06
# 3  2020                        Malawi  1.871            0.10
# 4  2020                        Rwanda  1.372            0.10
# 5  2020                         Niger  2.817            0.12
# 6  2020                  Sierra Leone  1.026            0.12
# 7  2020                        Uganda  5.538            0.12
# 8  2020                          Chad  2.279            0.14
# 9  2020                    Madagascar  3.964            0.14

# %%
demo_prct_chng = functions.yearly_prct_chng(co2_countries.copy(), functions.column_creation, functions.prct_calculations)

# %%
demo_prct_chng[(demo_prct_chng['year'] == 2020) & (demo_prct_chng['country'].isin(['China', 'United States']))]
# Out:
#              country  year    population  pop_prct_chng  gdp  gdp_prct_chng  \
# 9120           China  2020  1.424930e+09           0.22  NaN            NaN
# 45776  United States  2020  3.359420e+08           0.49  NaN            NaN
#
#              co2  co2_prct_chng
# 9120   10914.012            1.8
# 45776   4714.628          -10.4

# %%
functions.dual_scatter('Total', co2_countries)

# %%
functions.dual_scatter('Canada', co2_countries)

# %%
functions.dual_scatter('China', co2_countries)

# %%
functions.dual_scatter('United States', co2_countries)

# %%
functions.dual_scatter('Mexico', co2_countries)

# %%
functions.dual_scatter('Russia', co2_countries)
